# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
ds=pd.read_excel('ENB2012_data.xlsx')
ds
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
df = ds.rename({'X1': 'Relative Compactness', 'X2': 'Surface Area', 'X3': 'Wall Area', 'X4': 'Roof Area', 'X5': 'Overall Height', 'X6': 'Orientation', 'X7': 'Glazing Area', 'X8': 'Glazing Area Distribution', 'Y1': 'Heating Load', 'Y2': 'Cooling Load'}, axis=1)  # new method

# %%
pd.plotting.scatter_matrix(df,figsize=(20,20))
# Out:
# <img src="data:image/png;base64,..." width="2000">
# array([[<AxesSubplot:xlabel='Relative Compactness', ylabel='Relative Compactness'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Relative Compactness'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Relative Compactness'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Relative Compactness'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Relative Compactness'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Relative Compactness'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Relative Compactness'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Relative Compactness'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Relative Compactness'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Relative Compactness'>],
#        [<AxesSubplot:xlabel='Relative Compactness', ylabel='Surface Area'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Surface Area'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Surface Area'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Surface Area'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Surface Area'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Surface Area'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Surface Area'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Surface Area'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Surface Area'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Surface Area'>],
#        [<AxesSubplot:xlabel='Relative Compactness', ylabel='Wall Area'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Wall Area'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Wall Area'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Wall Area'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Wall Area'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Wall Area'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Wall Area'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Wall Area'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Wall Area'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Wall Area'>],
#        [<AxesSubplot:xlabel='Relative Compactness', ylabel='Roof Area'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Roof Area'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Roof Area'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Roof Area'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Roof Area'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Roof Area'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Roof Area'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Roof Area'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Roof Area'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Roof Area'>],
#        [<AxesSubplot:xlabel='Relative Compactness', ylabel='Overall Height'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Overall Height'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Overall Height'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Overall Height'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Overall Height'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Overall Height'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Overall Height'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Overall Height'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Overall Height'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Overall Height'>],
#        [<AxesSubplot:xlabel='Relative Compactness', ylabel='Orientation'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Orientation'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Orientation'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Orientation'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Orientation'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Orientation'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Orientation'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Orientation'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Orientation'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Orientation'>],
#        [<AxesSubplot:xlabel='Relative Compactness', ylabel='Glazing Area'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Glazing Area'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Glazing Area'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Glazing Area'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Glazing Area'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Glazing Area'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Glazing Area'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Glazing Area'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Glazing Area'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Glazing Area'>],
#        [<AxesSubplot:xlabel='Relative Compactness', ylabel='Glazing Area Distribution'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Glazing Area Distribution'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Glazing Area Distribution'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Glazing Area Distribution'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Glazing Area Distribution'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Glazing Area Distribution'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Glazing Area Distribution'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Glazing Area Distribution'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Glazing Area Distribution'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Glazing Area Distribution'>],
#        [<AxesSubplot:xlabel='Relative Compactness', ylabel='Heating Load'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Heating Load'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Heating Load'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Heating Load'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Heating Load'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Heating Load'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Heating Load'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Heating Load'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Heating Load'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Heating Load'>],
#        [<AxesSubplot:xlabel='Relative Compactness', ylabel='Cooling Load'>,
#         <AxesSubplot:xlabel='Surface Area', ylabel='Cooling Load'>,
#         <AxesSubplot:xlabel='Wall Area', ylabel='Cooling Load'>,
#         <AxesSubplot:xlabel='Roof Area', ylabel='Cooling Load'>,
#         <AxesSubplot:xlabel='Overall Height', ylabel='Cooling Load'>,
#         <AxesSubplot:xlabel='Orientation', ylabel='Cooling Load'>,
#         <AxesSubplot:xlabel='Glazing Area', ylabel='Cooling Load'>,
#         <AxesSubplot:xlabel='Glazing Area Distribution', ylabel='Cooling Load'>,
#         <AxesSubplot:xlabel='Heating Load', ylabel='Cooling Load'>,
#         <AxesSubplot:xlabel='Cooling Load', ylabel='Cooling Load'>]],
#       dtype=object)

# %% [markdown]
# <h2>3D scatter plot</h2>

# %% [markdown]
# <h3>X1 , X2 and Y1</h3>

# %%
# %matplotlib notebook
plt.figure(figsize=(10,5))
ax=plt.axes(projection='3d')
ax.scatter3D(ds['X1'],ds['X2'],ds['Y1'],c='red')
ax.set_xlabel('Relative Compactness')
ax.set_ylabel('Surface Area')
ax.set_zlabel('Heating Load')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 0, 'Heating Load')

# %% [markdown]
# <h3>X1 , X3 and Y1</h3>

# %%
# %matplotlib notebook
plt.figure(figsize=(10,5))
ax=plt.axes(projection='3d')
ax.scatter3D(ds['X1'],ds['X3'],ds['Y1'],c='blue')
ax.set_xlabel('Relative Compactness')
ax.set_ylabel('Wall Area')
ax.set_zlabel('Heating Load')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 0, 'Heating Load')

# %% [markdown]
# <h2>Regression for X1,X2,Y1</h2>

# %%
X=ds.iloc[:,0:2].values
y=ds.iloc[:,-2].values

# %%
regressor = LinearRegression()
model=regressor.fit(X, y)
y_pred = regressor.predict(X)

# %%
coefficient=regressor.coef_
print('co-efficient:',coefficient)
mse = mean_squared_error(y, y_pred)
print('mean Squared error:',mse)
cod=regressor.score(X, y);
print('co-efficient of determination:',cod)
# Out:
# co-efficient: [-180.46407789   -0.29034094]
# mean Squared error: 51.76945337056413
# co-efficient of determination: 0.4908572727954862

# %% [markdown]
# <h2>Regression for X1,X3,Y1</h2>

# %%
X=ds.iloc[:,[0,2]].values
y=ds.iloc[:,-2].values

# %%
regressor = LinearRegression()
model=regressor.fit(X, y)
y_pred = regressor.predict(X)

# %%
coefficient=regressor.coef_
print('co-efficient:',coefficient)
mse = mean_squared_error(y, y_pred)
print('mean Squared error:',mse)
cod=regressor.score(X, y);
print('co-efficient of determination:',cod)
# Out:
# co-efficient: [71.17238032  0.14055624]
# mean Squared error: 26.314295019664694
# co-efficient of determination: 0.7412039135341899
