# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
ds=pd.read_csv('fish.csv',header=None,index_col=0)

# %%
dia=pd.plotting.scatter_matrix(ds,figsize=(5,5))

# %% [markdown]
# ## 3D scatter plot

# %%
# %matplotlib notebook
plt.figure(figsize=(10,5))
ax=plt.axes(projection='3d')
ax.scatter3D(ds[1],ds[2],ds[3],c='red')
ax.set_xlabel('age')
ax.set_ylabel('temperature')
ax.set_zlabel('length')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 0, 'length')

# %% [markdown]
# <h2>Linear regression on full data set</h2>

# %%
X=ds.iloc[:,:-1].values
y=ds.iloc[:,-1].values

# %%
#having intecept as false, so while determining yplace intercept value is not used
regressor = LinearRegression(fit_intercept=False)
regressor.fit(X, y)
regressor.predict(X)
# Out:
# array([1108.76686697, 1490.68045472, 1845.31450049, 2227.22808825,
#        2609.141676  , 2991.05526375, 3372.9688515 , 3754.88243925,
#        4136.796027  , 4518.70961476, 4900.62320251, 1166.91512931,
#        1548.82871706, 1903.46276283, 2285.37635058, 2667.28993833,
#        3049.20352609, 3431.11711384, 3813.03070159, 4194.94428934,
#        4576.85787709, 4958.77146485, 1225.06339165, 1606.9769794 ,
#        1961.61102517, 2343.52461292, 2725.43820067, 3107.35178842,
#        3489.26537618, 3871.17896393, 4253.09255168, 4635.00613943,
#        5016.91972718, 1283.21165399, 1665.12524174, 2019.75928751,
#        2401.67287526, 2783.58646301, 3165.50005076, 3547.41363851,
#        3929.32722627, 4311.24081402, 4693.15440177, 5075.06798952])

# %%
coefficient=regressor.coef_
print('co-efficient:',coefficient)
mse = mean_squared_error(y, y_pred)
print('mean Squared error:',mse)
cod=regressor.score(X, y);
print('co-efficient of determination:',cod)
# Out:
# co-efficient: [27.27954198 29.07413117]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 coefficient=regressor.coef_
#       2 print('co-efficient:',coefficient)
# ----> 3 mse = mean_squared_error(y, y_pred)
#       4 print('mean Squared error:',mse)
#       5 cod=regressor.score(X, y);
#
# NameError: name 'y_pred' is not defined

# %%
# %matplotlib notebook
plt.figure(figsize=(10,5))
ax = plt.axes(projection = '3d')
ax.scatter3D(ds[1],ds[2],ds[3],c='red')
ax.set_xlabel('age')
ax.set_ylabel('temperature')
ax.set_zlabel('length')
#mgrid creates a 2d array with the given data
x1,x2=np.mgrid[0:180:20,25:33:2]
y_plane = x1*regressor.coef_[0]+ x2 * regressor.coef_[1] 
##the intercept value is made 0, so not using intercept value
#y_plane = x1*regressor.coef_[0]+ x2 * regressor.coef_[1] + regressor.intercept_
ax.plot_wireframe(x1,x2,y_plane)
#ax.plot_surface(x1,x2,y_plane)
dia=plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
